# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns',None)

# %%
df = pd.read_csv('gurgaon_properties_cleaned_v2.csv')

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 2          flat                pyramid elite   sector 86   0.46
# 3          flat       breez global hill view  sohna road   0.32
# 4          flat  bestech park view sanskruti   sector 92   1.60
#
#    price_per_sqft     area                                       areaWithType  \
# 0          7585.0   1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8600.0   1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 2            79.0  58228.0                 Carpet area: 58141 (5401.48 sq.m.)
# 3          5470.0    585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 4          8020.0   1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# 0        3         2       2       2.0         NaN        New Property
# 1        2         2       2       4.0         NaN        New Property
# 2        2         2       1       0.0         NaN  Under Construction
# 3        2         2       1      17.0         NaN        New Property
# 4        3         4      3+      10.0  North-West      Relatively New
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               1081.0            NaN        650.0           0             0
# 1                  NaN            NaN       1103.0           1             1
# 2                  NaN            NaN      58141.0           0             0
# 3                  NaN         1000.0        585.0           0             0
# 4               1995.0         1615.0       1476.0           0             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0             8
# 1           0           0       0                0            38
# 2           0           0       0                0            15
# 3           0           0       0                0            49
# 4           0           0       1                1           174

# %% [markdown]
# ## PROPERTY_TYPE VS PRICE

# %%
sns.barplot(x=df['property_type'],y=df['price'],estimator = np.median,color='blue',hue=df['property_type'],palette='Set2',legend=False)
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
sns.boxplot(x=df['property_type'],y=df['price'])
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
x = df[df['property_type'] == 'flat']

# %%
x[x['price'] > 4.5].shape
# Out:
# (131, 23)

# %%
x = df[df['property_type'] == 'house']
x[x['price'] > 16].shape
# Out:
# (30, 23)

# %% [markdown]
# # OBSERVATION
# * The prices of house are more as compared to the flats
# * There are outliers for both flats and houses
# * Number of outliers for flat is more as compared to houses

# %% [markdown]
# **PROPERTY_TYPE  VS  PRICE_PER_SQFT**

# %%
sns.barplot(x=df['property_type'],y=df['price_per_sqft'],estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
sns.boxplot(x=df['property_type'],y=df['price_per_sqft'])
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
#dropped the futhermost two outlier of house
df = df[df['price_per_sqft']<350000]

# %%
x = df[df['property_type'] == 'flat']

# %%
x[x['price_per_sqft']>150000]
# Out:
#      property_type             society     sector  price  price_per_sqft  \
# 2418          flat  ambience caitriona  sector 24   14.0        200000.0
# 3090          flat  ambience caitriona  sector 24   14.0        200000.0
#
#        area                      areaWithType  bedRoom  bathroom balcony  \
# 2418  700.0  Built Up area: 700 (65.03 sq.m.)        4         5       3
# 3090  700.0  Built Up area: 700 (65.03 sq.m.)        4         5       3
#
#       floorNum facing agePossession  super_built_up_area  built_up_area  \
# 2418       3.0   East     Undefined                  NaN          700.0
# 3090       3.0   East     Undefined                  NaN          700.0
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 2418          NaN           0             0           0           0       0
# 3090          NaN           0             0           0           0       0
#
#       furnishing_type  luxury_score
# 2418                0             0
# 3090                0             0

# %%
#dropped the futhermost single value of flat 
df = df.drop([2418,3090])

# %%
sns.boxplot(x=df['property_type'],y=df['price_per_sqft'])
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %% [markdown]
# **PROPERTY_TYPE  VS  BEDROOM**

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['bedRoom']))
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
sns.boxplot(x=df['property_type'],y=df['bedRoom'])
# Out:
# <Axes: xlabel='property_type', ylabel='bedRoom'>

# %%
df[df['bedRoom']>10].shape
# Out:
# (49, 23)

# %% [markdown]
# **PROPERTY_TYPE VS AREA**

# %%
sns.barplot(x=df['property_type'],y=df['area'],estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='area'>

# %%
sns.boxplot(x=df['property_type'],y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
#Removing the outlier 
df[df['built_up_area']>700000]
# Out:
#      property_type            society      sector  price  price_per_sqft  \
# 1648          flat  hcbs sports ville  sohna road   0.35             4.0
#
#           area                           areaWithType  bedRoom  bathroom  \
# 1648  875000.0  Built Up area: 737147 (68483.2 sq.m.)        2         2
#
#      balcony  floorNum facing   agePossession  super_built_up_area  \
# 1648       2       8.0    NaN  Relatively New                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 1648       737147.0          NaN           0             0           0
#
#       pooja room  others  furnishing_type  luxury_score
# 1648           0       0                2            44

# %%
df.drop(1648)
# Out:
#      property_type                              society      sector  price  \
# 0             flat              signature global park 4   sector 36   0.82
# 1             flat                     smart world gems   sector 89   0.95
# 2             flat                        pyramid elite   sector 86   0.46
# 3             flat               breez global hill view  sohna road   0.32
# 4             flat          bestech park view sanskruti   sector 92   1.60
# ...            ...                                  ...         ...    ...
# 3798          flat                       pivotal devaan   sector 84   0.37
# 3799         house  international city by sobha phase 1  sector 109   6.00
# 3800          flat           ansal api celebrity suites    sector 2   0.60
# 3801         house                          independent   sector 43  15.50
# 3802          flat                           m3m ikonic   sector 68   1.78
#
#       price_per_sqft     area  \
# 0             7585.0   1081.0
# 1             8600.0   1105.0
# 2               79.0  58228.0
# 3             5470.0    585.0
# 4             8020.0   1995.0
# ...              ...      ...
# 3798          6346.0    583.0
# 3799          9634.0   6228.0
# 3800          8163.0    735.0
# 3801         28233.0   5490.0
# 3802          9128.0   1950.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 0     Super Built up area 1081(100.43 sq.m.)Carpet a...        3         2
# 1                      Carpet area: 1103 (102.47 sq.m.)        2         2
# 2                    Carpet area: 58141 (5401.48 sq.m.)        2         2
# 3     Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...        2         2
# 4     Super Built up area 1995(185.34 sq.m.)Built Up...        3         4
# ...                                                 ...      ...       ...
# 3798  Super Built up area 583(54.16 sq.m.)Carpet are...        2         2
# 3799                         Plot area 692(578.6 sq.m.)        5         5
# 3800               Super Built up area 735(68.28 sq.m.)        1         1
# 3801                        Plot area 610(510.04 sq.m.)        5         6
# 3802  Super Built up area 1950(181.16 sq.m.)Built Up...        3         3
#
#      balcony  floorNum      facing       agePossession  super_built_up_area  \
# 0          2       2.0         NaN        New Property               1081.0
# 1          2       4.0         NaN        New Property                  NaN
# 2          1       0.0         NaN  Under Construction                  NaN
# 3          1      17.0         NaN        New Property                  NaN
# 4         3+      10.0  North-West      Relatively New               1995.0
# ...      ...       ...         ...                 ...                  ...
# 3798       1       5.0  North-West      Relatively New                583.0
# 3799      3+       2.0  South-West      Relatively New                  NaN
# 3800       1       5.0  North-East      Moderately Old                735.0
# 3801       3       3.0        East      Moderately Old                  NaN
# 3802      3+      27.0       South      Relatively New               1950.0
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 0               NaN        650.0           0             0           0
# 1               NaN       1103.0           1             1           0
# 2               NaN      58141.0           0             0           0
# 3            1000.0        585.0           0             0           0
# 4            1615.0       1476.0           0             1           0
# ...             ...          ...         ...           ...         ...
# 3798            NaN        483.0           0             0           0
# 3799         6228.0          NaN           1             1           1
# 3800            NaN          NaN           0             0           0
# 3801         5490.0          NaN           1             1           1
# 3802         1845.0       1530.0           0             0           0
#
#       pooja room  others  furnishing_type  luxury_score
# 0              0       0                0             8
# 1              0       0                0            38
# 2              0       0                0            15
# 3              0       0                0            49
# 4              0       1                1           174
# ...          ...     ...              ...           ...
# 3798           0       0                0            73
# 3799           1       0                0           160
# 3800           0       0                1            67
# 3801           1       0                0            76
# 3802           0       0                1           126
#
# [3780 rows x 23 columns]

# %% [markdown]
# **PROPERTY_TYPE  VS  FLOOR_NUM**

# %%
sns.barplot(x=df['property_type'],y=df['floorNum'],estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
sns.boxplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
#Checking for outlier
df[(df['property_type'] == 'house') & (df['floorNum']>10)].head(2)
# Out:
#     property_type            society     sector  price  price_per_sqft  \
# 35          house        greenopolis  sector 89   0.70          5397.0
# 106         house  suncity avenue 76  sector 76   0.75         10067.0
#
#        area                                       areaWithType  bedRoom  \
# 35   1297.0                  Built Up area: 1297 (120.5 sq.m.)        2
# 106   745.0  Plot area 745(69.21 sq.m.)Built Up area: 745 s...        2
#
#      bathroom balcony  floorNum      facing agePossession  \
# 35          2       2      14.0  North-East     Undefined
# 106         2       2      11.0  North-East  New Property
#
#      super_built_up_area  built_up_area  carpet_area  study room  \
# 35                   NaN         1297.0          NaN           0
# 106                  NaN          745.0          NaN           0
#
#      servant room  store room  pooja room  others  furnishing_type  \
# 35              0           0           0       0                0
# 106             0           0           0       0                0
#
#      luxury_score
# 35              0
# 106            40

# %%
# conclusion houses(villa) but in appartments

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['agePossession']))
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='agePossession',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
plt.figure(figsize=(13,4))
sns.heatmap(pd.pivot_table(df,index='property_type',columns='bedRoom',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['furnishing_type']),annot=True,fmt='.2f')
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='furnishing_type',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
plt.figure(figsize=(5,4))
sns.barplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum', 'facing',
#        'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study room', 'servant room', 'store room', 'pooja room', 'others',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %%
plt.figure(figsize=(15,4))
sns.heatmap(pd.crosstab(df['property_type'],df['sector'].sort_index()))
# Out:
# <Axes: xlabel='sector', ylabel='property_type'>

# %%
import re
avg_price_sectorwise = df.groupby('sector')['price'].mean().reset_index()

def sector_number(sector_name):
    match = re.search(r'\d+',sector_name)
    if match:
        return int(match.group())
    else:
        return float('inf')

avg_price_sectorwise['sector_number'] = avg_price_sectorwise['sector'].apply(sector_number)
avg_price_per_sector_sorted_by_sector = avg_price_sectorwise.sort_values(by='sector_number')

# Plotting the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sector_sorted_by_sector.set_index('sector')[['price']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Average Price per Sector (Sorted by Sector Number)')
plt.xlabel('Average Price')
plt.ylabel('Sector')
plt.show()

# %%
avg_price_per_sqft_sector_wise = df.groupby('sector')['price_per_sqft'].mean().reset_index()
avg_price_per_sqft_sector_wise['sector_number'] = avg_price_per_sqft_sector_wise['sector'].apply(sector_number)

avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector_wise.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sqft_sector_sorted_by_sector.set_index('sector')[['price_per_sqft']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
luxury_score = df.groupby('sector')['luxury_score'].mean().reset_index()
luxury_score['sector_number']=luxury_score['sector'].apply(sector_number)

luxury_score_sector_wise = luxury_score.sort_values(by='sector_number')

plt.figure(figsize=(5,20))
sns.heatmap(luxury_score_sector_wise.set_index('sector')[['luxury_score']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %% [markdown]
# **PRICE**

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x=df[df['area']<10000]['area'],y=df['price'],hue=df['bedRoom'])
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x=df[df['area']<10000]['area'],y=df['price'],hue=df['agePossession'])
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
sns.barplot(x=df['agePossession'],y=df['price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **Correlation**

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])

sns.heatmap(numeric_df.corr())
# Out:
# <Axes: >
