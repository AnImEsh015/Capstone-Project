# %%
import pandas as pd
import numpy as np
import re

# %%
flats = pd.read_csv('flats_cleaned.csv')
houses = pd.read_csv('house_cleaned.csv')

# %%
flats.head(2)
# Out:
#                   property_name                 society  price  \
# 0  2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1     2 BHK Flat in Ashok Vihar            apna enclave   0.50
#
#            sector  price_per_sqft                    areaWithType  bedRoom  \
# 0  krishna colony          5000.0  Carpet area: 900 (83.61 sq.m.)        2
# 1     ashok vihar          7692.0  Carpet area: 650 (60.39 sq.m.)        2
#
#    bathroom balcony additionalRoom  ... noOfFloor  facing    agePossession  \
# 0         2       1  not available  ...       4.0    West  1 to 5 Year Old
# 1         2       1  not available  ...       1.0    West     10+ Year Old
#
#                                      nearbyLocations  \
# 0  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
#
#                                          description  \
# 0  So with lift.Maa bhagwati residency is one of ...
# 1  Property situated on main road, railway statio...
#
#                                       furnishDetails  \
# 0  ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'N...
# 1  ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Ge...
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1  ['Security / Fire Alarm', 'Maintenance Staff',...
#
#                                               rating property_id   area
# 0  ['Environment4 out of 5', 'Safety4 out of 5', ...   C68850746  900.0
# 1  ['Environment4 out of 5', 'Safety4 out of 5', ...   H68850564  650.0
#
# [2 rows x 21 columns]

# %%
houses.head(2)
# Out:
#                                       property_name property_type  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon         house
# 1  5 Bedroom House for sale in Sector 21A Faridabad         house
#
#             society  price  price_per_sqft  area_sqft  \
# 0  bptp visionnaire   5.25         20115.0     2610.0
# 1       independent   5.70        105751.0      539.0
#
#                   areaWithType  bedRoom  bathroom balcony  \
# 0  Plot area 290(242.48 sq.m.)        5         4      3+
# 1   Plot area 539(50.07 sq.m.)        5         4       2
#
#                        additionalRoom  \
# 0                        servant room
# 1  store room,pooja room,servant room
#
#                                      address  noOfFloor      facing  \
# 0  29b, Sector 70A Gurgaon, Gurgaon, Haryana        3.0  North-East
# 1     Sector 21A Faridabad, Gurgaon, Haryana        2.0         NaN
#
#       agePossession                                    nearbyLocations  \
# 0   0 to 1 Year Old  ['Good Earth City Center 2', 'Kunskapsskolan I...
# 1  5 to 10 Year Old                                                NaN
#
#                                          description  \
# 0  Do you wish to buy an independent house in sec...
# 1  Hi, we have an independent house/villa availab...
#
#                                       furnishDetails  \
# 0  ['1 Wardrobe', '1 Fan', '1 Exhaust Fan', '1 Ge...
# 1  ['1 Water Purifier', '5 Fan', '1 Exhaust Fan',...
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 1  ['Private Garden / Terrace', 'Park', 'Visitor ...
#
#                                               rating
# 0  ['Environment5 out of 5', 'Lifestyle4 out of 5...
# 1                                                NaN

# %%
flats.rename(columns={'area':'area_sqft'},inplace = True)

# %%
flats.insert(loc=1,column='property_type',value='flat')

# %%
df = pd.concat([flats,houses],ignore_index = True)

# %%
df = df.sample(df.shape[0],ignore_index = True)

# %%
df.head(2)
# Out:
#                                    property_name property_type      society  \
# 0  3 Bedroom House for sale in Sector 33 Gurgaon         house  nitin vihar
# 1              2 BHK Flat in Ashok Vihar Phase 2          flat  shyam sadan
#
#    price               sector  price_per_sqft                    areaWithType  \
# 0   0.85                  NaN          9444.0      Plot area 900(83.61 sq.m.)
# 1   0.55  ashok vihar phase 2          6470.0  Carpet area: 700 (65.03 sq.m.)
#
#    bedRoom  bathroom balcony  ... noOfFloor facing    agePossession  \
# 0        3         2       0  ...       1.0   West  1 to 5 Year Old
# 1        2         2       1  ...       4.0   West  1 to 5 Year Old
#
#                                      nearbyLocations  \
# 0  ['Rajiv Chowk Mosque', 'Airforce Hospital', 'S...
# 1  ['Sheetla Mata Mandir', 'Chintapurni Mandir', ...
#
#                                          description  \
# 0  Independent house available for sale in nitin ...
# 1  One of the best locations in gurugram as gurga...
#
#                                       furnishDetails  \
# 0                                                NaN
# 1  ['2 Wardrobe', '1 Water Purifier', '5 Fan', '1...
#
#                                             features  \
# 0  ['High Ceiling Height', 'Water Storage', 'No o...
# 1  ['Security / Fire Alarm', 'Lift(s)', 'Water pu...
#
#                                               rating property_id area_sqft
# 0  ['Environment3 out of 5', 'Lifestyle4 out of 5...         NaN     900.0
# 1  ['Environment3 out of 5', 'Safety4 out of 5', ...   B68487870     850.0
#
# [2 rows x 22 columns]

# %%
df.shape
# Out:
# (3961, 22)

# %%
df.drop(col)
