# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows',None) 
pd.set_option('display.max_columns',None)

# %%
df = pd.read_csv('gurgaon_properties.csv')

# %%
df.head(2)
# Out:
#                                    property_name property_type      society  \
# 0  3 Bedroom House for sale in Sector 33 Gurgaon         house  nitin vihar
# 1              2 BHK Flat in Ashok Vihar Phase 2          flat  shyam sadan
#
#    price               sector  price_per_sqft                    areaWithType  \
# 0   0.85                  NaN          9444.0      Plot area 900(83.61 sq.m.)
# 1   0.55  ashok vihar phase 2          6470.0  Carpet area: 700 (65.03 sq.m.)
#
#    bedRoom  bathroom balcony additionalRoom  \
# 0        3         2       0  not available
# 1        2         2       1     study room
#
#                                  address  noOfFloor facing    agePossession  \
# 0    Sector 33 Gurgaon, Gurgaon, Haryana        1.0   West  1 to 5 Year Old
# 1  Ashok Vihar Phase 2, Gurgaon, Haryana        4.0   West  1 to 5 Year Old
#
#                                      nearbyLocations  \
# 0  ['Rajiv Chowk Mosque', 'Airforce Hospital', 'S...
# 1  ['Sheetla Mata Mandir', 'Chintapurni Mandir', ...
#
#                                          description  \
# 0  Independent house available for sale in nitin ...
# 1  One of the best locations in gurugram as gurga...
#
#                                       furnishDetails  \
# 0                                                NaN
# 1  ['2 Wardrobe', '1 Water Purifier', '5 Fan', '1...
#
#                                             features  \
# 0  ['High Ceiling Height', 'Water Storage', 'No o...
# 1  ['Security / Fire Alarm', 'Lift(s)', 'Water pu...
#
#                                               rating  area_sqft
# 0  ['Environment3 out of 5', 'Lifestyle4 out of 5...      900.0
# 1  ['Environment3 out of 5', 'Safety4 out of 5', ...      850.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3961 entries, 0 to 3960
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3961 non-null   object
#  1   property_type    3961 non-null   object
#  2   society          3960 non-null   object
#  3   price            3941 non-null   float64
#  4   sector           2997 non-null   object
#  5   price_per_sqft   3941 non-null   float64
#  6   areaWithType     3961 non-null   object
#  7   bedRoom          3961 non-null   int64
#  8   bathroom         3961 non-null   int64
#  9   balcony          3961 non-null   object
#  10  additionalRoom   3961 non-null   object
#  11  address          3950 non-null   object
#  12  noOfFloor        3940 non-null   float64
#  13  facing           2784 non-null   object
#  14  agePossession    3960 non-null   object
#  15  nearbyLocations  3754 non-null   object
#  16  description      3961 non-null   object
#  17  furnishDetails   2929 non-null   object
#  18  features         3252 non-null   object
#  19  rating           3511 non-null   object
#  20  area_sqft        3941 non-null   float64
# dtypes: float64(4), int64(2), object(15)
# memory usage: 650.0+ KB

# %%
df.drop(columns = 'sector',inplace=True)

# %%
df.shape
# Out:
# (3961, 20)

# %%
df.isna().sum()
# Out:
# property_name         0
# property_type         0
# society               1
# price                20
# price_per_sqft       20
# areaWithType          0
# bedRoom               0
# bathroom              0
# balcony               0
# additionalRoom        0
# address              11
# noOfFloor            21
# facing             1177
# agePossession         1
# nearbyLocations     207
# description           0
# furnishDetails     1032
# features            709
# rating              450
# area_sqft            20
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.insert(loc=3,column='sector',value=df['property_name'].str.split('in').str.get(1).str.replace('Gurgaon','').str.strip())

# %%
df.head(2)
# Out:
#                                    property_name property_type      society  \
# 0  3 Bedroom House for sale in Sector 33 Gurgaon         house  nitin vihar
# 1              2 BHK Flat in Ashok Vihar Phase 2          flat  shyam sadan
#
#                 sector  price  price_per_sqft                    areaWithType  \
# 0            Sector 33   0.85          9444.0      Plot area 900(83.61 sq.m.)
# 1  Ashok Vihar Phase 2   0.55          6470.0  Carpet area: 700 (65.03 sq.m.)
#
#    bedRoom  bathroom balcony additionalRoom  \
# 0        3         2       0  not available
# 1        2         2       1     study room
#
#                                  address  noOfFloor facing    agePossession  \
# 0    Sector 33 Gurgaon, Gurgaon, Haryana        1.0   West  1 to 5 Year Old
# 1  Ashok Vihar Phase 2, Gurgaon, Haryana        4.0   West  1 to 5 Year Old
#
#                                      nearbyLocations  \
# 0  ['Rajiv Chowk Mosque', 'Airforce Hospital', 'S...
# 1  ['Sheetla Mata Mandir', 'Chintapurni Mandir', ...
#
#                                          description  \
# 0  Independent house available for sale in nitin ...
# 1  One of the best locations in gurugram as gurga...
#
#                                       furnishDetails  \
# 0                                                NaN
# 1  ['2 Wardrobe', '1 Water Purifier', '5 Fan', '1...
#
#                                             features  \
# 0  ['High Ceiling Height', 'Water Storage', 'No o...
# 1  ['Security / Fire Alarm', 'Lift(s)', 'Water pu...
#
#                                               rating  area_sqft
# 0  ['Environment3 out of 5', 'Lifestyle4 out of 5...      900.0
# 1  ['Environment3 out of 5', 'Safety4 out of 5', ...      850.0

# %%
df['sector'].isna().sum()
# Out:
# np.int64(0)

# %%
df['sector']=df['sector'].str.lower()

# %%
df['sector'].value_counts()

# %%
df['sector'] = df['sector'].str.replace('dharam colony','sector 12')
df['sector'] = df['sector'].str.replace('krishna colony','sector 7')
df['sector'] = df['sector'].str.replace('suncity','sector 54')
df['sector'] = df['sector'].str.replace('prem nagar','sector 13')
df['sector'] = df['sector'].str.replace('mg road','sector 28')
df['sector'] = df['sector'].str.replace('gandhi nagar','sector 28')
df['sector'] = df['sector'].str.replace('laxmi garden','sector 11')
df['sector'] = df['sector'].str.replace('shakti nagar','sector 11')

# %%
df['sector'] = df['sector'].str.replace('baldev nagar','sector 7')
df['sector'] = df['sector'].str.replace('shivpuri','sector 7')
df['sector'] = df['sector'].str.replace('garhi harsaru','sector 17')
df['sector'] = df['sector'].str.replace('imt manesar','manesar')
df['sector'] = df['sector'].str.replace('adarsh nagar','sector 12')
df['sector'] = df['sector'].str.replace('shivaji nagar','sector 11')
df['sector'] = df['sector'].str.replace('bhim nagar','sector 6')
df['sector'] = df['sector'].str.replace('madanpuri','sector 7')

# %%
df['sector'] = df['sector'].str.replace('saraswati vihar','sector 28')
df['sector'] = df['sector'].str.replace('arjun nagar','sector 8')
df['sector'] = df['sector'].str.replace('ravi nagar','sector 9')
df['sector'] = df['sector'].str.replace('vishnu garden','sector 105')
df['sector'] = df['sector'].str.replace('bhondsi','sector 11')
df['sector'] = df['sector'].str.replace('surya vihar','sector 21')
df['sector'] = df['sector'].str.replace('devilal colony','sector 9')
df['sector'] = df['sector'].str.replace('valley view estate','gwal pahari')

# %%
df['sector'] = df['sector'].str.replace('mehrauli  road','sector 14')
df['sector'] = df['sector'].str.replace('jyoti park','sector 7')
df['sector'] = df['sector'].str.replace('ansal plaza','sector 23')
df['sector'] = df['sector'].str.replace('dayanand colony','sector 6')
df['sector'] = df['sector'].str.replace('sushant lok phase 2','sector 55')
df['sector'] = df['sector'].str.replace('chakkarpur','sector 28')
df['sector'] = df['sector'].str.replace('greenwood city','sector 45')
df['sector'] = df['sector'].str.replace('subhash nagar','sector 12')

# %%
df['sector'] = df['sector'].str.replace('sohna road road','sohna road')
df['sector'] = df['sector'].str.replace('malibu town','sector 47')
df['sector'] = df['sector'].str.replace('surat nagar 1','sector 104')
df['sector'] = df['sector'].str.replace('new colony','sector 7')
df['sector'] = df['sector'].str.replace('mianwali colony','sector 12')
df['sector'] = df['sector'].str.replace('jacobpura','sector 12')
df['sector'] = df['sector'].str.replace('rajiv nagar','sector 13')
df['sector'] = df['sector'].str.replace('ashok vihar','sector 3')

# %%
df['sector'] = df['sector'].str.replace('dlf phase 1','sector 26')
df['sector'] = df['sector'].str.replace('nirvana country','sector 50')
df['sector'] = df['sector'].str.replace('palam vihar','sector 2')
df['sector'] = df['sector'].str.replace('dlf phase 2','sector 25')
df['sector'] = df['sector'].str.replace('sushant lok phase 1','sector 43')
df['sector'] = df['sector'].str.replace('laxman vihar','sector 4')
df['sector'] = df['sector'].str.replace('dlf phase 4','sector 28')
df['sector'] = df['sector'].str.replace('dlf phase 3','sector 24')

# %%
df['sector'] = df['sector'].str.replace('sushant lok phase 3','sector 57')
df['sector'] = df['sector'].str.replace('dlf phase 5','sector 43')
df['sector'] = df['sector'].str.replace('rajendra park','sector 105')
df['sector'] = df['sector'].str.replace('uppals southend','sector 49')
df['sector'] = df['sector'].str.replace('sohna','sohna road')
df['sector'] = df['sector'].str.replace('ashok vihar phase 3 extension','sector 5')
df['sector'] = df['sector'].str.replace('south city 1','sector 41')
df['sector'] = df['sector'].str.replace('ashok vihar phase 2','sector 5')

# %%
a = df['sector'].value_counts()[df['sector'].value_counts()>=3]

# %%
df = df[df['sector'].isin(a.index)]

# %%
df['sector'].value_counts()

# %%
df['sector'] = df['sector'].str.replace('sector 95a','sector 95')
df['sector'] = df['sector'].str.replace('sector 23a','sector 23')
df['sector'] = df['sector'].str.replace('sector 12a','sector 12')
df['sector'] = df['sector'].str.replace('sector 3a','sector 3')
df['sector'] = df['sector'].str.replace('sector 110 a','sector 110')
df['sector'] = df['sector'].str.replace('patel nagar','sector 15')
df['sector'] = df['sector'].str.replace('a block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('maruti kunj','sector 12')
df['sector'] = df['sector'].str.replace('b block sector 43','sector 43')

# %%
df['sector'] = df['sector'].str.replace('sector-33 sohna road','sector 33')
df['sector'] = df['sector'].str.replace('sector 1 manesar','manesar')
df['sector'] = df['sector'].str.replace('sector 4 phase 2','sector 4')
df['sector'] = df['sector'].str.replace('sector 1a manesar','manesar')
df['sector'] = df['sector'].str.replace('c block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector 89 a','sector 89')
df['sector'] = df['sector'].str.replace('sector 2 extension','sector 2')
df['sector'] = df['sector'].str.replace('sector 36 sohna road','sector 36')

# %%
df[df['sector'] == 'new']
# Out:
#                   property_name property_type                       society  \
# 230   4 BHK Flat in New Gurgaon          flat                    sare homes
# 3444  2 BHK Flat in New Gurgaon          flat                   green court
# 3452  4 BHK Flat in New Gurgaon          flat                        dlf 76
# 3676  2 BHK Flat in New Gurgaon          flat  takshila heights sector 37 c
#
#      sector  price  price_per_sqft                            areaWithType  \
# 230     new   0.85          4786.0     Super Built up area 1776(165 sq.m.)
# 3444    new   0.38          5507.0           Carpet area: 690 (64.1 sq.m.)
# 3452    new   4.00         11428.0        Carpet area: 3500 (325.16 sq.m.)
# 3676    new   0.67          5583.0  Super Built up area 1200(111.48 sq.m.)
#
#       bedRoom  bathroom balcony           additionalRoom  \
# 230         4         4       3            not available
# 3444        2         2       1            not available
# 3452        4         4       2  study room,servant room
# 3676        2         2       2            not available
#
#                             address  noOfFloor facing       agePossession  \
# 230   New Gurgaon, Gurgaon, Haryana        3.0    NaN    5 to 10 Year Old
# 3444  New Gurgaon, Gurgaon, Haryana        7.0    NaN  Under Construction
# 3452  New Gurgaon, Gurgaon, Haryana        4.0    NaN            Jun 2027
# 3676  New Gurgaon, Gurgaon, Haryana        3.0    NaN     1 to 5 Year Old
#
#                                         nearbyLocations  \
# 230   ['Columbia Asia Hospital', 'Apex Multi Special...
# 3444  ['Ing bank ATM', 'Dcb bank ATM', 'Indus ind ba...
# 3452  ['Shri Balaji Hospital and Trauma Center', 'S....
# 3676  ['Shri Balaji Hospital and Trauma Center', 'S....
#
#                                             description  \
# 230   Located in the popular residential address of ...
# 3444  We are the proud owners of this 2 bhk apartmen...
# 3452  This lovely 4 bhk apartment/flat in new gurgao...
# 3676  Check out this 2 bhk apartment for sale in tak...
#
#                                          furnishDetails  \
# 230                                                  []
# 3444                                                 []
# 3452  ['6 Wardrobe', '1 Fridge', '8 Fan', '1 Exhaust...
# 3676                                                 []
#
#                                                features rating  area_sqft
# 230                                                 NaN    NaN     1776.0
# 3444  ['Intercom Facility', 'Lift(s)', 'Maintenance ...    NaN      690.0
# 3452  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...    NaN     3500.0
# 3676  ['Lift(s)', 'Swimming Pool', 'Visitor Parking'...    NaN     1200.0

# %%
df.loc[230,'sector'] = 'sector 81'
df.loc[3444,'sector'] = 'sector 81'
df.loc[3452,'sector'] = 'sector 81'
df.loc[3676,'sector'] = 'sector 81'

# %%
df['sector'].value_counts()

# %%
df['sector'] = df['sector'].str.replace('sector 99a','sector 99')
df['sector'] = df['sector'].str.replace('sector 88a','sector 88')
df['sector'] = df['sector'].str.replace('sector 67a','sector 67')
df['sector'] = df['sector'].str.replace('sector 82a','sector 82')
df['sector'] = df['sector'].str.replace('sector 63a','sector 63')
df['sector'] = df['sector'].str.replace('sector 82a','sector 82')
df['sector'] = df['sector'].str.replace('sector 36a','sector 36')
df['sector'] = df['sector'].str.replace('sector 9a','sector 9')
df['sector'] = df['sector'].str.replace('sector 10a','sector 10')
df['sector'] = df['sector'].str.replace('sector 17b','sector 17')
df['sector'] = df['sector'].str.replace('sector 88b','sector 88')

# %%
df['sector'] = df['sector'].str.replace('sector 17a','sector 17')
df['sector'] = df['sector'].str.replace('sector 9b','sector 9')
df['sector'] = df['sector'].str.replace('sector-5 sohna','sector 5')
df['sector'] = df['sector'].str.replace('sector 12 near sadar bazar','sector 12')
df['sector'] = df['sector'].str.replace('part 3 sector 5','sector 5')
df['sector'] = df['sector'].str.replace('urban estate, sector 5','sector 5')
df['sector'] = df['sector'].str.replace('sector-35 sohna','sector 35')
df['sector'] = df['sector'].str.replace('block h sector 3 phase iii extension','sector 3')

# %%
df['sector'] = df['sector'].str.replace('sector 50 pocket h','sector 50')
df['sector'] = df['sector'].str.replace('sector-5 sheetla colony','sector 5')
df['sector'] = df['sector'].str.replace('sector-7 hous','sector 7')
df['sector'] = df['sector'].str.replace('sector 17c','sector 17')
df['sector'] = df['sector'].str.replace('new sector 7','sector 7')
df['sector'] = df['sector'].str.replace('sector 21a faridabad ','sector 21')
df['sector'] = df['sector'].str.replace('sector 37a','sector 37')
df['sector'] = df['sector'].str.replace('sector 21a faridabad','sector 21')
df['sector'] = df['sector'].str.replace('v block sector 24','sector 24')

# %%
df['sector'].shape
# Out:
# (3803,)

# %%
df[df['sector'] == 'new sector 2']
# Out:
#                                     property_name property_type  \
# 1042                2 BHK Flat in New Palam Vihar          flat
# 1602  2 Bedroom House for sale in New Palam Vihar         house
# 1777  3 Bedroom House for sale in New Palam Vihar         house
# 3070                2 BHK Flat in New Palam Vihar          flat
# 3718                2 BHK Flat in New Palam Vihar          flat
#
#                   society        sector  price  price_per_sqft  \
# 1042              my home  new sector 2   0.22          4400.0
# 1602              my home  new sector 2   0.34         12592.0
# 1777          independent  new sector 2   1.00          8796.0
# 3070              my home  new sector 2   0.28          3166.0
# 3718  ompee k s residency  new sector 2   1.60         26936.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 1042                     Carpet area: 500 (46.45 sq.m.)        2         2
# 1602                         Plot area 270(25.08 sq.m.)        2         2
# 1777  Plot area 120(100.34 sq.m.)Built Up area: 120 ...        3         2
# 3070                     Carpet area: 900 (83.61 sq.m.)        2         1
# 3718                      Carpet area: 66 (55.18 sq.m.)        2         2
#
#      balcony additionalRoom  \
# 1042       1  not available
# 1602       2  not available
# 1777       2     pooja room
# 3070       1         others
# 3718       2  not available
#
#                                                 address  noOfFloor facing  \
# 1042                  New Palam Vihar, Gurgaon, Haryana        1.0    NaN
# 1602         Ez-19 A, New Palam Vihar, Gurgaon, Haryana        3.0   West
# 1777  Q-148, New Palam Vihar, Phase-2, Near Royal Oa...        1.0  North
# 3070         F 150/b, New Palam Vihar, Gurgaon, Haryana        2.0    NaN
# 3718                  New Palam Vihar, Gurgaon, Haryana        1.0    NaN
#
#          agePossession                                    nearbyLocations  \
# 1042   0 to 1 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 1602  5 to 10 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 1777      10+ Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 3070   1 to 5 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 3718   1 to 5 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
#
#                                             description  \
# 1042  Cctv surveillance are provided here. There is ...
# 1602  There are availability of various facilities l...
# 1777  Ground and first floor, Ground floor: Ground f...
# 3070  2 bhk room with wooden coverd ,1 drawing room,...
# 3718  We are the proud owners of this 2 bhk apartmen...
#
#                                          furnishDetails  \
# 1042  ['3 Fan', '1 Exhaust Fan', '15 Light', '1 Modu...
# 1602  ['1 Wardrobe', '3 Fan', '6 Light', 'No AC', 'N...
# 1777                                                NaN
# 3070  ['3 Wardrobe', '5 Light', '1 Chimney', '1 Modu...
# 3718                                                NaN
#
#                                           features  \
# 1042                                           NaN
# 1602  ['Water Storage', 'Park', 'Visitor Parking']
# 1777                                           NaN
# 3070                     ['Water Storage', 'Park']
# 3718                                           NaN
#
#                                                  rating  area_sqft
# 1042  ['Safety4 out of 5', 'Lifestyle4 out of 5', 'E...      500.0
# 1602  ['Environment4 out of 5', 'Lifestyle4 out of 5...      270.0
# 1777  ['Environment4 out of 5', 'Lifestyle4 out of 5...     1137.0
# 3070  ['Environment4 out of 5', 'Safety4 out of 5', ...      884.0
# 3718  ['Environment4 out of 5', 'Safety4 out of 5', ...      594.0

# %%
df.loc[[1042,1602,1777,3070,3718],'sector'] = 'sector 110'

# %%
df.shape
# Out:
# (3803, 21)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df1 = df.copy()

# %%
df1.drop(columns=['property_name', 'address', 'description', 'rating'],inplace=True)

# %%
df1.shape
# Out:
# (3803, 17)

# %%
df1.to_csv('gurgaon_properties_cleaned_v1.csv',index=False)
